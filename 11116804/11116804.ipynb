# %% [markdown]
# # Data Analysis Assignment
#
# # Kafu Kemeh
#
# ## 11116804
#
# ### CPEN

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Insights

# %%
wine = pd.read_csv('red_wine.csv')

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Returns the first 5 rows of the Dataset

# %%
wine.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %% [markdown]
# ### Returns the last 20 rows of the dataset

# %%
wine.shape
# Out:
# (1599, 12)

# %% [markdown]
# ### Returns a tuple showing the number of rows and columns

# %%
wine.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1053            8.3              0.33         0.42             2.3      0.070
# 1170            9.2              0.36         0.34             1.6      0.062
# 636             9.6              0.88         0.28             2.4      0.086
# 829             5.9              0.61         0.08             2.1      0.071
# 1122            6.3              0.47         0.00             1.4      0.055
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1053                  9.0                  20.0  0.99426  3.38       0.77
# 1170                  5.0                  12.0  0.99667  3.20       0.67
# 636                  30.0                 147.0  0.99790  3.24       0.53
# 829                  16.0                  24.0  0.99376  3.56       0.77
# 1122                 27.0                  33.0  0.99220  3.45       0.48
#
#       alcohol  quality
# 1053     12.7      7.0
# ...

# %% [markdown]
# ### Returns a specified number of random rows.

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# ### Returns Basic Information on the Dataset

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ### Returns Statistical Information on the Dataset

# %%
wine.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# ### Checks if there are any null values in the wine dataset

# %%
wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3.0           8.360000          0.884500     0.171000        2.635000
# 4.0           7.779245          0.693962     0.174151        2.694340
# 5.0           8.163971          0.577041     0.243686        2.528855
# 6.0           8.346311          0.497689     0.273501        2.478257
# 7.0           8.872362          0.403920     0.375176        2.720603
# 8.0           8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3.0       0.122500            11.000000             24.900000  0.997464
# 4.0       0.090679            12.264151             36.245283  0.996542
# 5.0       0.092768            16.967647             56.513950  0.997101
# 6.0       0.084978            15.690738             40.839874  0.996615
# 7.0       0.076588            14.045226             35.020101  0.996104
# ...

# %% [markdown]
# ### Sorts the rows in ascending order by quality

# %%
x = wine.density
y = wine.pH
plt.scatter(x,y)
plt.title('Scatter Plot')
plt.xlabel('density/g/cm^3')
plt.ylabel('pH')
plt.show()

# %% [markdown]
# ### A Scatter Plot - Density vs pH
#
# The scatter plot shows that there is a slight negative correlation between density and pH in the data. As the density increases, the pH levels tend to decrease. The correlation is not very strong but the downward trend is visible. This relationship makes intuitive sense - wines with higher density/sugar content tend to be more acidic with lower pH.
# There are no major outliers in the data. The scatter plot shows clustering of points with densities between 0.99 and 1.00 g/cm^3 and pH between 3.0 and 3.4. This range contains a majority of the wines.
# In summary, the scatter plot provides insight into the relationship between density and pH in the wine data. There are opportunities for further analysis by coloring the points based on other attributes, overlaying regression lines, or investigating specific clusters. But overall, the negative correlation aligns with domain knowledge of wine chemistry.

# %%
wine.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# ##  Histogram Diagrams
#
# __Histograms were plotted for each of the features in the wine dataset to understand the distribution of the values. The histograms provide insight into the shape, central tendency and spread of the features.A histogram with 50 bins was plotted for each of the features in the wine dataset to understand the distribution of the variables.__
#
# - The histogram for alcohol content shows a near normal distribution, with a peak around 10% alcohol. Most wines fall in the alcohol range of 8% to 14%. There are a few outliers on the lower end with alcohol < 8%.
#
# - The histogram of density shows a strong right-skew distribution, with most wines having a density between 0.99 and 1.00 g/cm^3. Only a very small number of wines have a density outside this range.
#
# - The sulfur dioxide histogram indicates two peaks - one around 20-40 and the other around 140-160. This is likely because sulfur dioxide is added at two stages in the wine making process. The bimodal distribution highlights that most wines have SO2 additions at one of those two levels.
#
# - The citric acid histogram is right-skewed with a peak near 0 g/L. Most wines have low citric acid content of 0-1 g/L while only a few outliers have higher levels.
#
# In summary, the histograms provide a statistical snapshot of the distribution of key variables. They highlight central tendencies, shapes, clusters and outliers for each feature. This analysis can inform deeper investigations into the impact of composition on wine quality.__

# %%
wine.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity               AxesSubplot(0.125,0.71587;0.168478x0.16413)
# volatile acidity         AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# citric acid              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# residual sugar           AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# chlorides                  AxesSubplot(0.125,0.518913;0.168478x0.16413)
# free sulfur dioxide     AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# total sulfur dioxide    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# density                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# pH                         AxesSubplot(0.125,0.321957;0.168478x0.16413)
# sulphates               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# alcohol                 AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# quality                 AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %% [markdown]
# ## Box and Whisker Plots
#
# __Boxplots were created for each of the 12 features in the wine dataset to visually inspect their distributions. The boxplots reveal several insights:__
#
# - The median quality score is around 5 to 6, with a few high-end outliers. This suggests most wines are average, with some exceptional ones.
#
# - Features like alcohol, pH, chlorides exhibit approximate normal distributions, clustered around the median.
# - Citric acid, volatile acidity and sulphates are right-skewed, with most wines having low values.
#
# - There are potential outliers, like wines with extreme alcohol, volatile acidity and chlorides values. Further investigation is required to assess if these are errors.
#
# - No differentiation is observed between red and white wines. Both exhibit similar spreads, indicating composition is more indicative of quality than wine type.
# - Residual sugar has a wide spread of values, highlighting diversity in wine sweetness levels.
#
# In summary, the boxplots reveal the underlying distributions of the features. When combined with histograms, they provide a robust statistical snapshot and help identify relationships to explore further. Key non-normal features like citric acid and quality scores are apparent. The next step is correlation analysis between features and quality to derive actionable insights.
#
# In the future, separating the boxplots by wine type or quality clusters may reveal additional patterns. But overall, these plots are an informative first step in the data analysis.

# %% [markdown]
# ## Conclusion
#
# There are a number of potential relationships that could be further analyzed between features.
# Additional statistical analysis and modeling could help predict wine quality from physicochemical properties.
# This initial exploratory analysis provides some interesting insights into the dataset that could be further investigated. The plots help visualize the data distributions, correlations, and potential patterns. More advanced analysis would be needed to draw further conclusions. The markdown annotations explain and document the key findings.
